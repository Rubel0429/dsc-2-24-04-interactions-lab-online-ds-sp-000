# %% [markdown]
# # Interactions - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll explore interactions in the Boston Housing data set.

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# - Understand what interactions are
# - Understand how to accommodate for interactions in regression

# %% [markdown]
# ## Build a baseline model

# %% [markdown]
# You'll use a couple of built-in functions, which we imported for you below.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.datasets import load_boston
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Import the Boston data set using `load_boston()`. We won't bother to preprocess the data in this lab. If you still want to build a model in the end, you can do that, but this lab will just focus on finding meaningful insights in interactions and how they can improve $R^2$ values.

# %%
regression = LinearRegression()
boston = load_boston()

# %% [markdown]
# Create a baseline model which includes all the variables in the Boston housing data set to predict the house prices. The use 10-fold cross-validation and report the mean $R^2$ value as the baseline $R^2$.

# %%
## code here
df = pd.DataFrame(boston.data, columns = boston.feature_names)
y = pd.DataFrame(boston.target,columns = ["target"])
all_data = pd.concat([y,df], axis = 1)

crossvalidation = KFold(n_splits=10, shuffle=True, random_state=1)
baseline = np.mean(cross_val_score(regression, df, y, scoring="r2", cv=crossvalidation))

# %%
baseline
# Out:
# 0.7189415144723073

# %% [markdown]
# ## See how interactions improve your baseline

# %% [markdown]
# Next, create all possible combinations of interactions, loop over them and add them to the baseline model one by one to see how they affect the R^2. We'll look at the 3 interactions which have the biggest effect on our R^2, so print out the top 3 combinations.
#
# You will create a for loop to loop through all the combinations of 2 predictors. You can use `combinations` from itertools to create a list of all the pairwise combinations. To find more info on how this is done, have a look [here](https://docs.python.org/2/library/itertools.html).

# %%
from itertools import combinations
combinations = list(combinations(boston.feature_names, 2))
df2 = df.copy()
interactions = []
for c in combinations:
    df2["interaction"] = df2[c[0]] * df2[c[1]]
    score = np.mean(cross_val_score(regression, df2, y, scoring="r2", cv=crossvalidation))
    if score > baseline: interactions.append((c[0], c[1], round(score,3)))

# %%
## code to find top 3 interactions by R^2 value here

print(sorted(interactions, key=lambda inter: inter[2], reverse=True)[:3])
# Out:
# [('RM', 'LSTAT', 0.786), ('RM', 'TAX', 0.775), ('RM', 'RAD', 0.768)]

# %% [markdown]
# ## Look at the top 3 interactions: "RM" as a confounding factor

# %% [markdown]
# The top three interactions seem to involve "RM", the number of rooms as a confounding variable for all of them. Let's have a look at interaction plots for all three of them. This exercise will involve:
#
# - splitting our data up in 3 groups: one for houses with a few rooms, one for houses with a "medium" amount of rooms, one for a high amount of rooms.
# - Create a function `build_interaction_rm`. This function takes an argument `varname` (which can be set equal to the column name as a string) and a column `description` (which describes the variable or varname, to be included on the x-axis of the plot). The function outputs a plot that uses "RM" as a confounding factor.

# %% [markdown]
# We split the data set for high, medium and low amount of rooms for you.

# %%
rm = np.asarray(df[["RM"]]).reshape(len(df[["RM"]]))

# %%
high_rm = all_data[rm > np.percentile(rm, 67)]
med_rm = all_data[(rm > np.percentile(rm, 33)) & (rm <= np.percentile(rm, 67))]
low_rm = all_data[rm <= np.percentile(rm, 33)]

# %% [markdown]
# Create `build_interaction_rm`.

# %%
def build_interaction_rm(varname, description):
    figure = plt.figure(figsize=(12,6))
    plt.scatter(high_rm[str(varname)],high_rm['target'],label='High Rooms')
    plt.scatter(med_rm[str(varname)],med_rm['target'],label='Medium Rooms')
    plt.scatter(low_rm[str(varname)],low_rm['target'],label="Low Rooms")
    
    high = LinearRegression()
    med = LinearRegression()
    low = LinearRegression()
    high.fit(high_rm[varname].values.reshape(-1, 1), high_rm["target"])
    med.fit(med_rm[varname].values.reshape(-1, 1), med_rm["target"])
    low.fit(low_rm[varname].values.reshape(-1, 1), low_rm["target"])

    # Make predictions using the testing set
    pred_high = high.predict(high_rm[varname].values.reshape(-1, 1))
    pred_med = med.predict(med_rm[varname].values.reshape(-1, 1))
    pred_low = low.predict(low_rm[varname].values.reshape(-1, 1))
    
    plt.plot(low_rm[varname], pred_low,  color='green')
    plt.plot(med_rm[varname], pred_med,  color='orange')
    plt.plot(high_rm[varname], pred_high,  color='blue')
    
    plt.ylabel("House Price")
    plt.xlabel(description)
    plt.legend()
    plt.show()

# %% [markdown]
# Next, use build_interaction_rm with the three variables that came out with the highest effect on $R^2$

# %%
# first plot
build_interaction_rm('LSTAT', 'Percentage of Lower Status')

# %%
# second plot
build_interaction_rm('TAX', 'Tax Rate')

# %%
build_interaction_rm('RAD', 'Highway Accessibility')

# %% [markdown]
# ## Build a final model including all three interactions at once

# %% [markdown]
# Use 10-fold crossvalidation.

# %%
# code here

# %%
df_new = df.copy()
df_new["RM_LSTAT"] = df["RM"] * df["LSTAT"]
df_new["RM_TAX"] = df["RM"] * df["TAX"]
df_new["RM_RAD"] = df["RM"] * df["RAD"]

final_model = np.mean(cross_val_score(regression, df_new, y, scoring="r2", cv=crossvalidation))
final_model
# Out:
# 0.7853084169016563

# %% [markdown]
# Our $R^2$ has increased considerably! Let's have a look in statsmodels to see if all these interactions are significant.

# %%
import statsmodels.api as sm
df_new_sm = sm.add_constant(df_new)
model = sm.OLS(y,df_new_sm)
results = model.fit()

results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 target   R-squared:                       0.815
# Model:                            OLS   Adj. R-squared:                  0.809
# Method:                 Least Squares   F-statistic:                     134.4
# Date:                Sun, 27 Jan 2019   Prob (F-statistic):          2.83e-167
# Time:                        12:02:23   Log-Likelihood:                -1413.8
# No. Observations:                 506   AIC:                             2862.
# Df Residuals:                     489   BIC:                             2933.
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -14.8281      7.426     -1.997      0.046     -29.419      -0.237
# ...

# %% [markdown]
# What is your conclusion here?

# %%
# formulate your conclusion
# Two out of three of the features we added are insignificant. It might be worth removing "RM_RAD" to see the effect it has on the signifcance of the other two features.

# %% [markdown]
# ## Summary

# %% [markdown]
# You now understand how to include interaction effects in your model!
